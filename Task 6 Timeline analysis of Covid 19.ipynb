# %% [markdown]
# ## Task 6:-Timeline analysis:-Covid 19

# %% [markdown]
# ### Import library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl
# %matplotlib inline
sns.set()

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv(r'owid-covid-data.csv')

# %%
#print first five row
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.498
# 1                         0.5            64.83                    0.498
# 2                         0.5            64.83                    0.498
# 3                         0.5            64.83                    0.498
# 4                         0.5            64.83                    0.498
#
# [5 rows x 50 columns]

# %%
#print last five row
df.tail()
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 58036      NaN       NaN  International  2020-11-16        696.0        NaN
# 58037      NaN       NaN  International  2020-11-17        696.0        NaN
# 58038      NaN       NaN  International  2020-11-18        696.0        NaN
# 58039      NaN       NaN  International  2020-11-19        696.0        NaN
# 58040      NaN       NaN  International  2020-11-20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 58036                 NaN           7.0         NaN                  NaN  ...
# 58037                 NaN           7.0         NaN                  NaN  ...
# 58038                 NaN           7.0         NaN                  NaN  ...
# 58039                 NaN           7.0         NaN                  NaN  ...
# 58040                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 58036             NaN              NaN                    NaN
# 58037             NaN              NaN                    NaN
# 58038             NaN              NaN                    NaN
# 58039             NaN              NaN                    NaN
# 58040             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 58036                  NaN             NaN           NaN
# 58037                  NaN             NaN           NaN
# 58038                  NaN             NaN           NaN
# 58039                  NaN             NaN           NaN
# 58040                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 58036                     NaN                         NaN              NaN
# 58037                     NaN                         NaN              NaN
# 58038                     NaN                         NaN              NaN
# 58039                     NaN                         NaN              NaN
# 58040                     NaN                         NaN              NaN
#
#        human_development_index
# 58036                      NaN
# 58037                      NaN
# 58038                      NaN
# 58039                      NaN
# 58040                      NaN
#
# [5 rows x 50 columns]

# %%
#print random five row
df.sample(5)
# Out:
#       iso_code      continent      location        date  total_cases  \
# 26529      ITA         Europe         Italy  2020-02-25        229.0
# 45658      SRB         Europe        Serbia  2020-09-08      31941.0
# 5531       BLZ  North America        Belize  2020-06-19         22.0
# 2925       AUS        Oceania     Australia  2020-07-12       9553.0
# 45121      SAU           Asia  Saudi Arabia  2020-09-07     320827.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 26529       97.0              32.286           6.0         4.0
# 45658       36.0              76.429         725.0         1.0
# 5531         0.0               0.286           2.0         0.0
# 2925       194.0             170.143         107.0         1.0
# 45121      895.0             858.000        4081.0        32.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 26529                0.857  ...       35220.084              2.0
# 45658                1.714  ...       14048.881              NaN
# 5531                 0.000  ...        7824.362              NaN
# 2925                 0.429  ...       44648.710              0.5
# 45121               30.143  ...       49045.411              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 26529                113.151                 4.78            19.8
# 45658                439.415                10.08            37.7
# 5531                 176.957                17.11             NaN
# 2925                 107.791                 5.07            13.0
# 45121                259.538                17.72             1.8
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 26529          27.8                     NaN                       3.180
# 45658          40.2                  97.719                       5.609
# 5531            NaN                  90.083                       1.300
# 2925           16.5                     NaN                       3.840
# 45121          25.4                     NaN                       2.700
#
#        life_expectancy  human_development_index
# 26529            83.51                    0.880
# 45658            76.00                    0.787
# 5531             74.62                    0.708
# 2925             83.44                    0.939
# 45121            75.13                    0.853
#
# [5 rows x 50 columns]

# %%
print(df.info())             #full summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58041 entries, 0 to 58040
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57715 non-null  object
#  1   continent                           57389 non-null  object
#  2   location                            58041 non-null  object
#  3   date                                58041 non-null  object
#  4   total_cases                         54403 non-null  float64
#  5   new_cases                           57112 non-null  float64
#  6   new_cases_smoothed                  56298 non-null  float64
#  7   total_deaths                        44955 non-null  float64
#  8   new_deaths                          57112 non-null  float64
#  9   new_deaths_smoothed                 56298 non-null  float64
#  10  total_cases_per_million             54113 non-null  float64
#  11  new_cases_per_million               57048 non-null  float64
#  12  new_cases_smoothed_per_million      56233 non-null  float64
#  13  total_deaths_per_million            44680 non-null  float64
#  14  new_deaths_per_million              57048 non-null  float64
#  15  new_deaths_smoothed_per_million     56233 non-null  float64
#  16  reproduction_rate                   37696 non-null  float64
#  17  icu_patients                        4624 non-null   float64
#  18  icu_patients_per_million            4624 non-null   float64
#  19  hosp_patients                       5196 non-null   float64
#  20  hosp_patients_per_million           5196 non-null   float64
#  21  weekly_icu_admissions               396 non-null    float64
#  22  weekly_icu_admissions_per_million   396 non-null    float64
#  23  weekly_hosp_admissions              696 non-null    float64
#  24  weekly_hosp_admissions_per_million  696 non-null    float64
#  25  total_tests                         22463 non-null  float64
#  26  new_tests                           22240 non-null  float64
#  27  total_tests_per_thousand            22463 non-null  float64
#  28  new_tests_per_thousand              22240 non-null  float64
#  29  new_tests_smoothed                  25147 non-null  float64
#  30  new_tests_smoothed_per_thousand     25147 non-null  float64
#  31  tests_per_case                      23245 non-null  float64
#  32  positive_rate                       23655 non-null  float64
#  33  tests_units                         26116 non-null  object
#  34  stringency_index                    48091 non-null  float64
#  35  population                          57715 non-null  float64
#  36  population_density                  54979 non-null  float64
#  37  median_age                          51600 non-null  float64
#  38  aged_65_older                       50822 non-null  float64
#  39  aged_70_older                       51331 non-null  float64
#  40  gdp_per_capita                      50927 non-null  float64
#  41  extreme_poverty                     33940 non-null  float64
#  42  cardiovasc_death_rate               51582 non-null  float64
#  43  diabetes_prevalence                 53471 non-null  float64
#  44  female_smokers                      40097 non-null  float64
#  45  male_smokers                        39585 non-null  float64
#  46  handwashing_facilities              24461 non-null  float64
#  47  hospital_beds_per_thousand          46439 non-null  float64
#  48  life_expectancy                     56971 non-null  float64
#  49  human_development_index             49795 non-null  float64
# dtypes: float64(45), object(5)
# memory usage: 22.1+ MB
# None

# %%
print(df.describe())    #statistical details of the dataset
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.440300e+04   57112.000000        56298.000000  4.495500e+04
# mean   1.720333e+05    1995.516774         1961.694522  6.949698e+03
# std    1.738104e+06   18743.363546        18239.299567  5.656797e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.840000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.121000e+03      14.000000           19.571000  8.600000e+01
# 75%    2.322500e+04     241.000000          251.143000  7.430000e+02
# max    5.698477e+07  647519.000000       592222.000000  1.360879e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  57112.000000         56298.000000             54113.000000
# mean      47.654153            47.298407              3229.165421
# std      396.700071           382.494997              6364.355653
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000                91.848000
# 50%        0.000000             0.286000               611.534000
# 75%        4.000000             4.143000              3565.256000
# max    11024.000000          9371.286000             78509.027000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           57048.000000                     56233.00000
# mean               40.457443                        39.47762
# std               136.092366                       103.94826
# min             -2212.545000                      -269.97800
# 25%                 0.000000                         0.26700
# 50%                 2.240500                         3.91900
# 75%                26.490000                        30.14500
# max              8652.658000                      2472.18800
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              44680.000000  ...    50927.000000     33940.000000
# mean                  96.773133  ...    20606.715513        12.452118
# std                  182.478226  ...    20304.308061        19.438372
# min                    0.000000  ...      661.240000         0.100000
# 25%                    4.040500  ...     5321.444000         0.500000
# 50%                   20.602500  ...    13913.839000         2.000000
# 75%                   93.663000  ...    31400.840000        18.100000
# max                 1299.612000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           51582.000000         53471.000000    40097.000000
# mean              252.734143             8.072236       10.740516
# std               117.540460             4.193925       10.470280
# min                79.370000             0.990000        0.100000
# 25%               156.139000             5.310000        1.900000
# 50%               238.339000             7.140000        6.400000
# 75%               318.991000            10.390000       19.600000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  39585.000000            24461.000000                46439.000000
# mean      32.640404               52.068445                    3.089050
# std       13.454191               31.646795                    2.512352
# min        7.700000                1.188000                    0.100000
# 25%       21.400000               21.222000                    1.300000
# 50%       31.400000               52.232000                    2.500000
# 75%       40.900000               83.741000                    4.200000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     56971.000000             49795.000000
# mean         73.933685                 0.722103
# std           7.398209                 0.153294
# min          53.280000                 0.354000
# 25%          69.870000                 0.601000
# 50%          75.290000                 0.752000
# 75%          79.380000                 0.847000
# max          86.750000                 0.953000
#
# [8 rows x 45 columns]

# %%
print(df.shape)      #shape of dataset
# Out:
# (58041, 50)

# %%
duplicate_rows_df = df[df.duplicated()]

print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 50)

# %%
df.count() #Used to count the number of rows
# Out:
# iso_code                              57715
# continent                             57389
# location                              58041
# date                                  58041
# total_cases                           54403
# new_cases                             57112
# new_cases_smoothed                    56298
# total_deaths                          44955
# new_deaths                            57112
# new_deaths_smoothed                   56298
# total_cases_per_million               54113
# new_cases_per_million                 57048
# new_cases_smoothed_per_million        56233
# total_deaths_per_million              44680
# new_deaths_per_million                57048
# new_deaths_smoothed_per_million       56233
# reproduction_rate                     37696
# icu_patients                           4624
# icu_patients_per_million               4624
# hosp_patients                          5196
# hosp_patients_per_million              5196
# weekly_icu_admissions                   396
# weekly_icu_admissions_per_million       396
# weekly_hosp_admissions                  696
# weekly_hosp_admissions_per_million      696
# total_tests                           22463
# new_tests                             22240
# total_tests_per_thousand              22463
# new_tests_per_thousand                22240
# new_tests_smoothed                    25147
# new_tests_smoothed_per_thousand       25147
# tests_per_case                        23245
# positive_rate                         23655
# tests_units                           26116
# stringency_index                      48091
# population                            57715
# population_density                    54979
# median_age                            51600
# aged_65_older                         50822
# aged_70_older                         51331
# gdp_per_capita                        50927
# extreme_poverty                       33940
# cardiovasc_death_rate                 51582
# diabetes_prevalence                   53471
# female_smokers                        40097
# male_smokers                          39585
# handwashing_facilities                24461
# hospital_beds_per_thousand            46439
# life_expectancy                       56971
# human_development_index               49795
# dtype: int64

# %%
df.isnull().sum()
# Out:
# iso_code                                326
# continent                               652
# location                                  0
# date                                      0
# total_cases                            3638
# new_cases                               929
# new_cases_smoothed                     1743
# total_deaths                          13086
# new_deaths                              929
# new_deaths_smoothed                    1743
# total_cases_per_million                3928
# new_cases_per_million                   993
# new_cases_smoothed_per_million         1808
# total_deaths_per_million              13361
# new_deaths_per_million                  993
# new_deaths_smoothed_per_million        1808
# reproduction_rate                     20345
# icu_patients                          53417
# icu_patients_per_million              53417
# hosp_patients                         52845
# hosp_patients_per_million             52845
# weekly_icu_admissions                 57645
# weekly_icu_admissions_per_million     57645
# weekly_hosp_admissions                57345
# weekly_hosp_admissions_per_million    57345
# total_tests                           35578
# new_tests                             35801
# total_tests_per_thousand              35578
# new_tests_per_thousand                35801
# new_tests_smoothed                    32894
# new_tests_smoothed_per_thousand       32894
# tests_per_case                        34796
# positive_rate                         34386
# tests_units                           31925
# stringency_index                       9950
# population                              326
# population_density                     3062
# median_age                             6441
# aged_65_older                          7219
# aged_70_older                          6710
# gdp_per_capita                         7114
# extreme_poverty                       24101
# cardiovasc_death_rate                  6459
# diabetes_prevalence                    4570
# female_smokers                        17944
# male_smokers                          18456
# handwashing_facilities                33580
# hospital_beds_per_thousand            11602
# life_expectancy                        1070
# human_development_index                8246
# dtype: int64

# %%
df1=df[["date","total_cases","new_cases","total_deaths","new_tests","total_tests"]]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2019-12-31          NaN        0.0           NaN        NaN          NaN
# 1  2020-01-01          NaN        0.0           NaN        NaN          NaN
# 2  2020-01-02          NaN        0.0           NaN        NaN          NaN
# 3  2020-01-03          NaN        0.0           NaN        NaN          NaN
# 4  2020-01-04          NaN        0.0           NaN        NaN          NaN

# %%
df1.mean()
# Out:
# total_cases     1.720333e+05
# new_cases       1.995517e+03
# total_deaths    6.949698e+03
# new_tests       2.886339e+04
# total_tests     2.384886e+06
# dtype: float64

# %%
df1.cov()
# Out:
#                total_cases     new_cases  total_deaths     new_tests  \
# total_cases   3.021005e+12  3.240532e+10  1.052545e+11  7.516081e+10
# new_cases     3.240532e+10  3.513137e+08  1.158339e+09  8.256360e+08
# total_deaths  1.052545e+11  1.158339e+09  3.199936e+09  1.974178e+09
# new_tests     7.516081e+10  8.256360e+08  1.974178e+09  1.348553e+10
# total_tests   7.300338e+12  6.940622e+10  1.879343e+11  1.189205e+12
#
#                total_tests
# total_cases   7.300338e+12
# new_cases     6.940622e+10
# total_deaths  1.879343e+11
# new_tests     1.189205e+12
# total_tests   1.179645e+14

# %%
df1.corr()
# Out:
#               total_cases  new_cases  total_deaths  new_tests  total_tests
# total_cases      1.000000   0.966472      0.974133   0.910831     0.945126
# new_cases        0.966472   1.000000      0.965174   0.884131     0.804901
# total_deaths     0.974133   0.965174      1.000000   0.835538     0.846193
# new_tests        0.910831   0.884131      0.835538   1.000000     0.917756
# total_tests      0.945126   0.804901      0.846193   0.917756     1.000000

# %%
df1.var()
# Out:
# total_cases     3.021005e+12
# new_cases       3.513137e+08
# total_deaths    3.199936e+09
# new_tests       1.348553e+10
# total_tests     1.179645e+14
# dtype: float64

# %%
df1.std()
# Out:
# total_cases     1.738104e+06
# new_cases       1.874336e+04
# total_deaths    5.656797e+04
# new_tests       1.161272e+05
# total_tests     1.086115e+07
# dtype: float64

# %% [markdown]
# ### Proper visualization of dataset

# %%
sns.distplot(df1['total_cases'])
sns.distplot(df1['new_cases']);

# %%
df1.plot(figsize = (10 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
sns.distplot(df1['total_tests'])
sns.distplot(df1['new_tests']);

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ### Trends and Seasonality in TimeSeries Dataset

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
sns.pairplot(df1, size=2.5)
# Out:
# C:\Users\ViNaY\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("new_cases", "total_cases", data=df1, kind='reg')

# %%
sns.distplot(df1['total_cases'], kde=False);
plt.axvline(0, color="k", linestyle="--");

# %%
sns.distplot(df1['new_cases'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['total_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['new_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
total_cases.diff().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20);

# %%
df1.total_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_cases=df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')
